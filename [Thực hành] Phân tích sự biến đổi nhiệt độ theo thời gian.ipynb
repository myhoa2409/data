# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("daily-min-temperatures.csv")
df
# Out:
#             Date  Temp
# 0     1981-01-01  20.7
# 1     1981-01-02  17.9
# 2     1981-01-03  18.8
# 3     1981-01-04  14.6
# 4     1981-01-05  15.8
# ...          ...   ...
# 3645  1990-12-27  14.0
# 3646  1990-12-28  13.6
# 3647  1990-12-29  13.5
# 3648  1990-12-30  15.7
# 3649  1990-12-31  13.0
#
# [3650 rows x 2 columns]

# %%
df.loc[:,'Temp'].describe()
# Out:
# count    3650.000000
# mean       11.177753
# std         4.071837
# min         0.000000
# 25%         8.300000
# 50%        11.000000
# 75%        14.000000
# max        26.300000
# Name: Temp, dtype: float64

# %%
# Vẽ biểu đồ Histogram

plt.hist(df.loc[:,'Temp'], bins = 45)
plt.show()

# %%
plt.hist(df['Temp'], bins = 45, range = (1, 23), histtype = 'step')
plt.title('Temperature Histogram', fontsize = 16)
plt.show()

# %%
# 7. Vẽ biểu đồ đường thể hiện xu hướng nhiệt độ

plt.plot(df.loc[:,'Date'], df.loc[:,'Temp'])
plt.title('Daily Temperature', fontsize = 16)
plt.xlabel('Date', fontsize = 14)
plt.ylabel('Temp', fontsize = 14)
plt.show()

# %%
df['Date'] = pd.to_datetime(df['Date'])
bounds = ['1/1/1990', '12/31/1990']
bounds = pd.to_datetime(bounds)
d1 = df[(df['Date'] >= bounds[0]) & (df['Date'] <= bounds[1])]
plt.plot(d1['Date'], d1['Temp'])
plt.title('Daily Temperature in 1990', fontsize = 16)
plt.xlabel('Date', fontsize = 14)
plt.ylabel('Temp', fontsize = 14)
plt.show()
