# %%
# khai báo thư viện
import pandas as pd
import numpy as np
print("nhập dự liệu thành công")
# Out:
# nhập dự liệu thành công

# %%
#nhập dự liệu
data = pd.read_csv('OnlineRetail.csv', header=0, encoding = "ISO-8859-1")
print('*'*20, "Nhập dữ liệu thành công", '*'*20)
display(data)
data.info()
# data2 = pd.read_csv('FoodPrice_in_Turkey.csv', header = 0, encoding = 'utf-8')
# display(data2)
# Out:
# ******************** Nhập dữ liệu thành công ********************
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %%
#tìm số hàng và số cột dự liệu
print("so hang la:", data.shape[0], "số cột là:",data.shape[1])
# Out:
# so hang la: 541909 số cột là: 8

# %%
#việt hóa tên các cột

data.columns = ['Số hóa đơn','mã hàng hóa','mô tả','số lượng','ngày','đơn giá','mã KH','nước']
display(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 #việt hóa tên các cột
# ----> 3 data.columns = ['Số hóa đơn','mã hàng hóa','mô tả','số lượng','ngày','đơn giá','mã KH','nước']
#       4 display(data)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5588, in NDFrame.__setattr__(self, name, value)
#    5586 try:
#    5587     object.__getattribute__(self, name)
# -> 5588     return object.__setattr__(self, name, value)
#    5589 except AttributeError:
#    5590     pass
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\properties.pyx:70, in pandas._libs.properties.AxisProperty.__set__()
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:769, in NDFrame._set_axis(self, axis, labels)
#     767 def _set_axis(self, axis: int, labels: Index) -> None:
#     768     labels = ensure_index(labels)
# ...

# %%
#thêm cột tiền vào sau cuối 
data["Tiền"] = np.NaN
display(data)
# Out:
#        Số hóa đơn mã hàng hóa                                mô tả  số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# # 4. thêm 1 cột chiết khấu sau đơn giá

# %%
# data.insert(8,'Chiết khấu (%)',np.random.randint(0,20,size=(data.shape[0], 1)))
display(data)
data.info()
# Out:
#        Số hóa đơn mã hàng hóa                                mô tả  số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905     581587       22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906     581587       23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# # 5. thêm 1 sản phẩm vào hàng thứ 541905
# ## thông tin sp: 3465536,325657, nồi chiên không dầu, 1000, 23/06/2022, 23, 3,2434, Thổ nhĩ kỳ, NaN

# %%
data.loc[541905]= [3465536,325657,'nồi chiên không dầu',1000,'23/06/2022',23.0,3,354665,"Thổ Nhĩ Kỳ",np.NaN]
data = data.sort_index().reset_index(drop=True)
display(data)
data.info()
# Out:
#        Số hóa đơn mã hàng hóa                                mô tả  số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    3465536      325657                  nồi chiên không dầu      1000
# 541906    3465536      325657                  nồi chiên không dầu      1000
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# # 6. tính tiền theo công thức sau
# tiền = số lượng x don giá x chiết khấu

# %%
data["Tiền"] = data['số lượng']*data['đơn giá']*(1-data['Chiết khấu (%)']/100)
display(data)
# Out:
#        Số hóa đơn mã hàng hóa                                mô tả  số lượng  \
# 0          536365      85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1          536365       71053                  WHITE METAL LANTERN         6
# 2          536365      84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3          536365      84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4          536365      84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...           ...         ...                                  ...       ...
# 541904     581587       22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    3465536      325657                  nồi chiên không dầu      1000
# 541906    3465536      325657                  nồi chiên không dầu      1000
# 541907     581587       23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908     581587       22138        BAKING SET 9 PIECE RETROSPOT          3
#
# ...

# %% [markdown]
# # lưu dữ liệu ra file
# data.to_excel('tenfile.xlsx')

# %%
data.to_excel("ketquahomnay.json")
print("xuất file thành công")
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\io\excel\_base.py:999, in ExcelWriter.__new__(cls, path, engine, date_format, datetime_format, mode, storage_options, if_sheet_exists, engine_kwargs, **kwargs)
#     998 try:
# --> 999     engine = config.get_option(f"io.excel.{ext}.writer", silent=True)
#    1000     if engine == "auto":
#
# File ~\anaconda3\lib\site-packages\pandas\_config\config.py:256, in CallableDynamicDoc.__call__(self, *args, **kwds)
#     255 def __call__(self, *args, **kwds):
# --> 256     return self.__func__(*args, **kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\_config\config.py:128, in _get_option(pat, silent)
#     127 def _get_option(pat: str, silent: bool = False):
# --> 128     key = _get_single_key(pat, silent)
#     130     # walk the nested dict
#
# ...
